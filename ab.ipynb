# %%
import face_recognition
image = face_recognition.load_image_file("/workspaces/codespaces-jupyter/abb.jpg")
face_locations = face_recognition.face_locations(image)
#model = "cnn"
#https://towardsdatascience.com/real-time-face-recognition-an-end-to-end-project-b738bb0f7348
#https://docs.opencv.org/3.3.0/dc/d88/tutorial_traincascade.html

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
img2 = cv2.imread('/workspaces/codespaces-jupyter/abb.jpg')
img2 = cv2.cvtColor(img2,cv2.COLOR_BGR2RGB)

# %%
for top,right,bottom,left in face_locations:
    cv2.rectangle(img2, (left, top), (right, bottom), (0, 0, 255),thickness=2)
plt.imshow(img2)

# %%
image2 = face_recognition.load_image_file('/workspaces/codespaces-jupyter/chr.jpg')
encoding = face_recognition.face_encodings(image2)[0]
img3 = cv2.imread('/workspaces/codespaces-jupyter/chr.jpg')
img3 = cv2.cvtColor(img3,cv2.COLOR_BGR2RGB)

# %%
image3 = face_recognition.load_image_file('/workspaces/codespaces-jupyter/crist.jpg')
encoding1 = face_recognition.face_encodings(image3)[0]
result = face_recognition.compare_faces([encoding],encoding1)
print(result)
# Out:
# [True]

# %%
# Out:
# 128
